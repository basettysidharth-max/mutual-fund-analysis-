# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-623bbc92-b6c0-4a16-9885-36826dab7f67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-623bbc92-b6c0-4a16-9885-36826dab7f67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

for file in uploaded.keys():
    print("\n" + "="*70)
    print("FILE:", file)

    df = pd.read_csv(file)

    print("\nShape:")
    print(df.shape)

    print("\nData Types:")
    print(df.dtypes)

    print("\nFirst 5 Rows:")
    print(df.head())

    print("\nMissing Values:")
    print(df.isnull().sum())

    print("\nDuplicate Rows:")
    print(df.duplicated().sum())
# Out:
# ...
# FILE: 01_fund_master.csv
#
# Shape:
# (40, 15)
#
# Data Types:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#
# First 5 Rows:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
import requests
import pandas as pd

scheme_code = "125497"

url = f"https://api.mfapi.in/mf/{scheme_code}"

response = requests.get(url)

data = response.json()

nav_df = pd.DataFrame(data["data"])

nav_df.to_csv("hdfc_top100_nav.csv", index=False)

print(nav_df.head())
# Out:
#          date        nav
# 0  01-06-2026  192.31950
# 1  31-05-2026  193.68360
# 2  29-05-2026  193.68480
# 3  27-05-2026  195.05010
# 4  26-05-2026  194.22580

# %%
fund_master = pd.read_csv("01_fund_master.csv")

print("Fund Houses:")
print(fund_master["fund_house"].unique())

print("\nCategories:")
print(fund_master["category"].unique())

print("\nSub Categories:")
print(fund_master["sub_category"].unique())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_616/3686540105.py in <cell line: 0>()
# ----> 1 fund_master = pd.read_csv("01_fund_master.csv")
#       2
#       3 print("Fund Houses:")
#       4 print(fund_master["fund_house"].unique())
#       5
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'hdfc_top100_nav.csv', 'sample_data']

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-db9464b6-0f48-4908-bec8-0cf580b1a1fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db9464b6-0f48-4908-bec8-0cf580b1a1fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', '05_category_inflows.csv', '06_industry_folio_count.csv', '01_fund_master (1).csv', '02_nav_history.csv', 'hdfc_top100_nav.csv', '01_fund_master.csv', '02_nav_history (1).csv', '06_industry_folio_count (1).csv', '04_monthly_sip_inflows.csv', '07_scheme_performance (1).csv', '03_aum_by_fund_house.csv', '09_portfolio_holdings.csv', '03_aum_by_fund_house (1).csv', '05_category_inflows (1).csv', '08_investor_transactions.csv', '08_investor_transactions (1).csv', '07_scheme_performance.csv', '09_portfolio_holdings (1).csv', '04_monthly_sip_inflows (1).csv', '10_benchmark_indices.csv', '10_benchmark_indices (1).csv', 'sample_data']

# %%
fund_master = pd.read_csv("01_fund_master.csv")

# %%
print("Fund Houses:")
print(fund_master["fund_house"].unique())

print("\nCategories:")
print(fund_master["category"].unique())

print("\nSub Categories:")
print(fund_master["sub_category"].unique())
# Out:
# Fund Houses:
# ['SBI Mutual Fund' 'HDFC Mutual Fund' 'ICICI Prudential MF'
#  'Nippon India MF' 'Kotak Mahindra MF' 'Axis Mutual Fund'
#  'Aditya Birla Sun Life MF' 'UTI Mutual Fund' 'Mirae Asset MF'
#  'DSP Mutual Fund']
#
# Categories:
# ['Equity' 'Debt']
#
# Sub Categories:
# ['Large Cap' 'Small Cap' 'Gilt' 'Mid Cap' 'Short Duration' 'Value'
#  'Liquid' 'Index/ETF' 'Flexi Cap' 'Index' 'Large & Mid Cap' 'ELSS']

# %%
import pandas as pd

fund_master = pd.read_csv("01_fund_master.csv")
nav_history = pd.read_csv("02_nav_history.csv")

print("Fund Master Columns:")
print(fund_master.columns)

print("\nNAV History Columns:")
print(nav_history.columns)
# Out:
# Fund Master Columns:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='object')
#
# NAV History Columns:
# Index(['amfi_code', 'date', 'nav'], dtype='object')

# %%
# Validate AMFI codes

fund_codes = set(fund_master["amfi_code"].astype(str))
nav_codes = set(nav_history["amfi_code"].astype(str))

missing_codes = fund_codes - nav_codes

print("Total AMFI Codes in Fund Master:", len(fund_codes))
print("Total AMFI Codes in NAV History:", len(nav_codes))
print("Missing Codes:", len(missing_codes))

if len(missing_codes) == 0:
    print("✅ All AMFI codes from fund_master exist in nav_history")
else:
    print("❌ Missing AMFI Codes:")
    print(list(missing_codes)[:10])
# Out:
# Total AMFI Codes in Fund Master: 40
# Total AMFI Codes in NAV History: 40
# Missing Codes: 0
# ✅ All AMFI codes from fund_master exist in nav_history

# %%
print("DATA QUALITY SUMMARY")
print("--------------------")
print("1. All datasets loaded successfully.")
print("2. No major missing values found in sampled datasets.")
print("3. No duplicate rows detected in benchmark indices dataset.")
print("4. Fund houses, categories and sub-categories explored.")
print("5. Live NAV data fetched successfully from mfapi.in.")
print("6. AMFI code validation completed.")
# Out:
# DATA QUALITY SUMMARY
# --------------------
# 1. All datasets loaded successfully.
# 2. No major missing values found in sampled datasets.
# 3. No duplicate rows detected in benchmark indices dataset.
# 4. Fund houses, categories and sub-categories explored.
# 5. Live NAV data fetched successfully from mfapi.in.
# 6. AMFI code validation completed.

# %%
import requests
import pandas as pd

scheme_codes = [119551, 120503, 118632, 119092, 120841]

nav_data = []

for code in scheme_codes:
    url = f"https://api.mfapi.in/mf/{code}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        nav_data.append({
            "amfi_code": code,
            "scheme_name": data["meta"]["scheme_name"],
            "latest_nav": data["data"][0]["nav"],
            "date": data["data"][0]["date"]
        })

nav_df = pd.DataFrame(nav_data)

print(nav_df)

nav_df.to_csv("live_nav_5_schemes.csv", index=False)
print("Saved successfully!")
# Out:
#    amfi_code                                        scheme_name  latest_nav  \
# 0     119551  Aditya Birla Sun Life Banking & PSU Debt Fund ...   104.70250
# 1     120503  Axis ELSS Tax Saver Fund - Direct Plan - Growt...   103.09480
# 2     118632  Nippon India Large Cap Fund - Direct Plan Grow...    97.19440
# 3     119092  HDFC Money Market Fund - Growth Option - Direc...  6156.75320
# 4     120841   quant Mid Cap Fund - Growth Option - Direct Plan   246.98140
#
#          date
# 0  01-06-2026
# 1  01-06-2026
# 2  01-06-2026
# 3  01-06-2026
# 4  01-06-2026
# Saved successfully!

# %% [markdown]
# # Data Quality Summary
#
# - Successfully loaded all 10 mutual fund datasets.
# - Verified dataset dimensions using .shape.
# - Checked column data types using .dtypes.
# - Reviewed sample records using .head().
# - Fetched live NAV data from mfapi.in.
# - Retrieved NAV data for 5 key mutual fund schemes.
# - Validated AMFI codes against NAV history data.
# - No major missing values, duplicate records, or data integrity issues were observed.
# - The datasets are suitable for further analysis and dashboard development.
